# %% [markdown]
# # Final Project Multivariate Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import rcParams
import warnings
warnings.filterwarnings('ignore')

# %%
rcParams['figure.figsize']  = 19,7
rcParams['lines.linewidth'] = 2.8
rcParams['xtick.labelsize'] = 'medium'
rcParams['ytick.labelsize'] = 'medium'
rcParams['axes.titlesize']  = 13
rcParams['axes.titleweight']  = 550
rcParams['axes.grid'] = True
rcParams['grid.alpha'] = 0.19
plt.rc('axes',axisbelow=True)
plt.rc('axes.spines',top=False,bottom=False,left=False,right=False)
pd.set_option('display.max_columns',100)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import rcParams
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('apartdata.csv')
df.head()
# Out:
#                                         Unit_Name  No_Rooms  Bathroom  \
# 0       Taman Sari Semanggi Apartment 1BR Tower A         1         1
# 1     Puri Park View Apartment 2BR Semi Furnished         2         1
# 2        Metro Park Residence 2BR Fully Furnished         2         1
# 3  Pondok Indah Golf Apartment 2BR View Golf Area         2         2
# 4               Season City Apartment 2BR Tower C         2         1
#
#        Locality           Region   Longitude  Latitude  Furnished  Area  \
# 0      Semanggi  Jakarta Selatan  106.819159 -6.226598          1  43.0
# 1   Kebon Jeruk    Jakarta Barat  106.756061 -6.192081          0  35.0
# 2        Kedoya    Jakarta Barat  106.757651 -6.186415          1  53.0
# 3  Pondok Indah  Jakarta Selatan  106.784600 -6.272637          1  85.0
# 4        Grogol    Jakarta Barat  106.796056 -6.153652          0  48.0
#
#          Tower  Total_Facilities Currency  Annual_Price
# 0      Tower A                23      IDR      96000000
# 1     Tower CB                19      IDR      30000000
# 2  Tower Milan                22      IDR      70000000
# 3      Tower -                24      IDR     576000000
# 4      Tower C                15      IDR      32000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5303 entries, 0 to 5302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unit_Name         5302 non-null   object
#  1   No_Rooms          5303 non-null   int64
#  2   Bathroom          5303 non-null   int64
#  3   Locality          5303 non-null   object
#  4   Region            5303 non-null   object
#  5   Longitude         5303 non-null   float64
#  6   Latitude          5303 non-null   float64
#  7   Furnished         5303 non-null   int64
#  8   Area              5303 non-null   float64
#  9   Tower             5303 non-null   object
#  10  Total_Facilities  5303 non-null   int64
#  11  Currency          5303 non-null   object
#  12  Annual_Price      5303 non-null   int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 538.7+ KB

# %%
df.describe()
# Out:
#           No_Rooms     Bathroom    Longitude     Latitude    Furnished  \
# count  5303.000000  5303.000000  5303.000000  5303.000000  5303.000000
# mean      1.517632     1.251367   106.836413    -6.196851     0.838959
# std       0.963900     0.525101     0.372240     0.475304     0.367603
# min       0.000000     0.000000   104.014900    -7.949100     0.000000
# 25%       1.000000     1.000000   106.784377    -6.237284     1.000000
# 50%       2.000000     1.000000   106.816842    -6.197352     1.000000
# 75%       2.000000     1.000000   106.851836    -6.175894     1.000000
# max       6.000000     5.000000   119.441818     6.304300     1.000000
#
#               Area  Total_Facilities  Annual_Price
# count  5303.000000       5303.000000  5.303000e+03
# mean     61.080454         19.405619  9.982642e+07
# std     158.657168          3.880148  9.618815e+07
# min       0.000000          0.000000  1.392000e+04
# 25%      33.000000         18.000000  4.200000e+07
# 50%      42.000000         20.000000  6.400000e+07
# 75%      73.000000         22.000000  1.200000e+08
# max    7781.000000         24.000000  1.296000e+09

# %%
df.duplicated().sum()
# Out:
# 115

# %% [markdown]
# There are 115 duplicated data

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(5)
# Out:
#                                               Unit_Name  No_Rooms  Bathroom  \
# 413        Bintaro Plaza Residence 1BR Tower The Breeze         1         1
# 4570              Kota Ayodhya Apartment 3BR Tower jade         3         2
# 3713  Grand Dhika City Apartment Studio Fully Furnished         0         1
# 2595                   MOI City Home 2BR Semi Furnished         2         1
# 4936             The Wave Apartment 1BR Fully Furnished         1         1
#
#            Locality           Region   Longitude  Latitude  Furnished  Area  \
# 413         Bintaro  Jakarta Selatan  106.742800 -6.273500          0  31.0
# 4570        Cikokol        Tangerang  106.629106 -6.199893          0  64.0
# 3713     Kalimalang           Bekasi  107.019700 -6.262100          1  25.0
# 2595  Kelapa Gading    Jakarta Utara  106.890391 -6.149836          0  45.0
# 4936       Kuningan  Jakarta Selatan  106.836847 -6.213647          1  47.0
#
#                  Tower  Total_Facilities Currency  Annual_Price
# 413   Tower The Breeze                10      IDR      38000000
# 4570        Tower jade                18      IDR      45000000
# 3713     Tower Cempaka                14      IDR      42000000
# 2595    Tower Hawaiian                22      IDR      33000000
# 4936       Tower Coral                20      IDR      90000000

# %%
df.isna().sum()
# Out:
# Unit_Name           1
# No_Rooms            0
# Bathroom            0
# Locality            0
# Region              0
# Longitude           0
# Latitude            0
# Furnished           0
# Area                0
# Tower               0
# Total_Facilities    0
# Currency            0
# Annual_Price        0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unit_Name           1
# No_Rooms            0
# Bathroom            0
# Locality            0
# Region              0
# Longitude           0
# Latitude            0
# Furnished           0
# Area                0
# Tower               0
# Total_Facilities    0
# Currency            0
# Annual_Price        0
# dtype: int64

# %% [markdown]
# Although a missing value exists in Unit_Name, there is no need to clean the data since such column won't be used in further analysis due to consist lots of unique values

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# In this project, we will only use apartment located in Jabodetabek. Thus, we need to omit the data outside of that area

# %%
df.Region.value_counts()
# Out:
# Jakarta Selatan    1498
# Jakarta Barat      1316
# Jakarta Pusat      1054
# Jakarta Utara       411
# Jakarta Timur       364
# Tangerang           317
# Bekasi              100
# Depok                65
# Bandung              33
# Surabaya             13
# Karawang              5
# Sumedang              4
# Bogor                 3
# Jogjakarta            1
# Semarang              1
# Malang                1
# Makassar              1
# Batam                 1
# Name: Region, dtype: int64

# %% [markdown]
# ## 2.1 Get apartment located in Jabodetabek

# %%
jakarta = df[df.Region.str.contains('Jakarta')]
bekasi = df[df.Region.str.contains('Bekasi')]
depok = df[df.Region.str.contains('Depok')]
tangerang = df[df.Region.str.contains('Tangerang')]

df_new = pd.concat([jakarta, bekasi, depok, tangerang],axis=0)
df_new.sample(6)
# Out:
#                                           Unit_Name  No_Rooms  Bathroom  \
# 4702       Park Royal Apartment 3BR Fully Furnished         3         2
# 1461  Casa De Parco Apartment Studio Tower Gardenia         0         1
# 5217         Signature Park Grande Studio View city         0         1
# 5140          Belleza Apartment 1BR Fully Furnished         1         1
# 883       Pakubuwono Terrace Studio Fully Furnished         0         1
# 3270      Capitol Suites Apartment Studio View Kota         0         1
#
#             Locality           Region   Longitude  Latitude  Furnished   Area  \
# 4702   Gatot Subroto    Jakarta Pusat  106.809240 -6.213072          1  187.0
# 1461        BSD City        Tangerang  106.652113 -6.306400          1   26.0
# 5217      MT Haryono    Jakarta Timur  106.866201 -6.245201          1   26.0
# 5140   Permata Hijau  Jakarta Selatan  106.783318 -6.220183          1   62.0
# 883   Kebayoran Lama  Jakarta Selatan  106.769194 -6.237472          1   23.0
# 3270         Menteng    Jakarta Pusat  106.838974 -6.180433          1   29.0
#
#                Tower  Total_Facilities Currency  Annual_Price
# 4702         Tower 1                23      IDR     324000000
# 1461  Tower Gardenia                22      IDR      48000000
# 5217     Tower Light                20      IDR      54000000
# 5140   Tower Albergo                23      IDR      96000000
# 883      Tower utara                19      IDR      48000000
# 3270   Tower Capitol                23      IDR      84000000

# %% [markdown]
# ## 2.2 Convert USD to IDR

# %%
df_new.Currency.value_counts()
# Out:
# IDR    5074
# USD      51
# Name: Currency, dtype: int64

# %% [markdown]
# There are still 51 apartments having the price in USD. We will convert them to IDR first so that the rent price would be equal for all of them

# %% [markdown]
# The exchange rate would be used from USD to IDR is Rp15,589 as today's its value ( 9 Dec, 2022 )

# %%
usd_apart_index = df_new[df_new.Currency=='USD'].index

df_new1 = df_new.copy()
df_new1.loc[usd_apart_index,'Annual_Price'] = df_new1.loc[usd_apart_index,'Annual_Price']*15589

df_new1.sample(6)
# Out:
#                                               Unit_Name  No_Rooms  Bathroom  \
# 3049               The Nest Apartment Studio  Furnished         0         1
# 3640              Signature Park Grande 1BR Tower Green         1         1
# 3850       Mutiara Executive Residences 3BR View Garden         3         3
# 3518         Cosmo Mansion - Thamrin City 2BR View City         2         1
# 2522  Mediterania Marina Ancol Apartment 2BR Fully F...         2         1
# 3911  Woodland Park Residence Kalibata Studio View City         0         1
#
#            Locality           Region   Longitude  Latitude  Furnished   Area  \
# 3049  Karang Tengah        Tangerang  106.723973 -6.195343          1   27.0
# 3640     MT Haryono    Jakarta Timur  106.866201 -6.245201          1   37.0
# 3850       Cilandak  Jakarta Selatan  106.812974 -6.278625          1  200.0
# 3518        Thamrin    Jakarta Pusat  106.818654 -6.194443          1   58.0
# 2522          Ancol    Jakarta Utara  106.829210 -6.128082          1   43.9
# 3911       Kalibata  Jakarta Selatan  106.855352 -6.255809          1   29.0
#
#                       Tower  Total_Facilities Currency  Annual_Price
# 3049                Tower B                21      IDR      40000000
# 3640            Tower Green                19      IDR      72000000
# 3850                Tower I                21      IDR     303600000
# 3518  Tower Cosmo Residence                20      IDR     100000000
# 2522                Tower D                21      IDR      60000000
# 3911            Tower Matoa                20      IDR      70000000

# %% [markdown]
# ## 2.3 Omitting zero bathroom apartment

# %% [markdown]
# It does make sense that an apartment is having zero "No_Rooms" as it represents Studio type.

# %% [markdown]
# However, it is kinda weird if the apartment not having bathroom since it is one of essential entities should exist in apartment/home. Thus, we're gonna remove them

# %%
df_new1 = df_new1[df_new['Bathroom']>0]
df_new1.sample(7)
# Out:
#                                               Unit_Name  No_Rooms  Bathroom  \
# 4692                Belmont Residence 1BR Tower Everest         1         1
# 3989             Botanica Apartment 2BR Fully Furnished         2         2
# 1054            Puri Orchard Apartment Studio View city         1         1
# 2614             Casablanca Mansion 2BR Fully Furnished         2         1
# 2212              Lavande Residence 2BR Fully Furnished         2         1
# 531   Serpong Green View Apartment Studio Tower Ambe...         0         1
# 806         Taman Anggrek Residence 2BR Fully Furnished         2         1
#
#             Locality           Region   Longitude  Latitude  Furnished   Area  \
# 4692     Kebon Jeruk    Jakarta Barat  106.762396 -6.200106          1   32.0
# 3989  Kebayoran Lama  Jakarta Selatan  106.789467 -6.232826          1  195.0
# 1054      Cengkareng    Jakarta Barat  106.729326 -6.166036          1   35.0
# 2614      Casablanca  Jakarta Selatan  106.846292 -6.222918          1   48.0
# 2212           Tebet  Jakarta Selatan  106.843171 -6.236462          1   55.0
# 531          Serpong        Tangerang  106.686600 -6.294000          1   21.0
# 806    Tanjung Duren    Jakarta Barat  106.791700 -6.179200          1   50.0
#
#                 Tower  Total_Facilities Currency  Annual_Price
# 4692    Tower Everest                16      IDR      40000000
# 3989          Tower 1                21      IDR     550850000
# 1054       Tower OG a                19      IDR      48750000
# 2614          Tower 1                24      IDR      96000000
# 2212          Tower C                20      IDR     100000000
# 531   Tower Amberwood                17      IDR      36000000
# 806     Tower Calypso                14      IDR      92000000

# %%
df_new1.shape
# Out:
# (5103, 13)

# %% [markdown]
# ## 2.4 Removing outliers

# %% [markdown]
# As in our analysis methods ( Regression and PCA ) are sentisive to outliers, we should remove them so that the results will be more robust and meaningful

# %% [markdown]
# ### 2.4.1 No_Rooms

# %%
sns.boxplot(x='No_Rooms',y='Annual_Price',data=df_new1)
plt.show()

# %% [markdown]
# An outlier exists in studio apartment. We may need to see the data first whether it should be removed or treated by statistical method

# %%
df_new1[df_new1.Annual_Price>1e16]
# Out:
# Empty DataFrame
# Columns: [Unit_Name, No_Rooms, Bathroom, Locality, Region, Longitude, Latitude, Furnished, Area, Tower, Total_Facilities, Currency, Annual_Price]
# Index: []

# %% [markdown]
# Turns out that the annual price currency is in USD and the annual price has been converted to IDR. There might be an error in the currency column when data inputing. Thus, we will get the value back before conversion

# %%
df_new1.loc[df_new1[df_new1.Annual_Price>1e16].index, 'Annual_Price'] = df_new1.loc[df_new1[df_new1.Annual_Price>1e16].index, 'Annual_Price']/15589

sns.boxplot(x='No_Rooms',y='Annual_Price',data=df_new1)
plt.show()

# %% [markdown]
# Three and Four no_rooms apartments look having outliers.

# %%
df_new1[df_new1.Annual_Price>1e13]
# Out:
# Empty DataFrame
# Columns: [Unit_Name, No_Rooms, Bathroom, Locality, Region, Longitude, Latitude, Furnished, Area, Tower, Total_Facilities, Currency, Annual_Price]
# Index: []

# %% [markdown]
# From the data above, the values actually are still reasonable when viewed from the area and location ( Jakarta Selatan is known as high society area )

# %% [markdown]
# However, for robust result sake in terms of statistics and the limitation of the methods would be used ( MLR and PCA ), this project is limited to the data that is not considered to be extreme outliers. For this reason, we will remove the values above

# %%
df_new1 = df_new1[df_new1.Annual_Price<1e13]

sns.boxplot(x='No_Rooms',y='Annual_Price',data=df_new1)
plt.show()

# %% [markdown]
# Same as the previous reasons, we will remove those values that seem to be considered extreme outliers

# %%
df_new1 = df_new1[df_new1.Annual_Price<0.3e13]

sns.boxplot(x='No_Rooms',y='Annual_Price',data=df_new1)
plt.show()

# %%
df_new1 = df_new1[df_new1.Annual_Price<8e11]

sns.boxplot(x='No_Rooms',y='Annual_Price',data=df_new1)
plt.show()

# %%
df_new1 = df_new1[df_new1.Annual_Price<1.2e9]

sns.boxplot(x='No_Rooms',y='Annual_Price',data=df_new1)
plt.show()

# %%
df_new1 = df_new1[~((df_new1.Annual_Price>1e9)&(df_new1.No_Rooms==3))]

sns.boxplot(x='No_Rooms',y='Annual_Price',data=df_new1, linewidth=1.3, fliersize=2)
plt.show()

# %% [markdown]
# From the boxplot above, it seems that already to make sense for each category of the number of rooms as, overall, the more rooms an apartment has, the more expensive it is

# %% [markdown]
# ## 2.4.2 Bathroom

# %%
sns.boxplot(x='Bathroom',y='Annual_Price',data=df_new1, linewidth=1.3, fliersize=2)
plt.show()

# %% [markdown]
# From this column, no extreme outliers exist

# %% [markdown]
# ## 2.4.3 Longitude and Latitude

# %%
fig, ax = plt.subplots(1,2, figsize= (15,9), sharey=True)

sns.scatterplot(x='Longitude',y='Annual_Price',data=df_new1,ax=ax[0])
sns.scatterplot(x='Latitude',y='Annual_Price',data=df_new1,ax=ax[1],color='tab:orange')
plt.show()

# %% [markdown]
# "Latitude" column has some unusual values which close to 6 as the most are exist near negative 6

# %%
df_new1[df_new1.Latitude > 6]
# Out:
#                                      Unit_Name  No_Rooms  Bathroom  \
# 826   Best Western Mangga Dua Studio View City         0         1
# 951            B Residence BSD 1BR Tower lotus         0         1
# 1140      B Residence BSD Studio Non Furnished         0         1
# 2344    B Residence BSD Studio Fully Furnished         0         1
# 3143         B Residence BSD Studio  Furnished         0         1
# 3175     B Residence BSD Studio View AEON Mall         0         1
# 4469         B Residence BSD Studio  Furnished         0         1
#
#         Locality         Region   Longitude  Latitude  Furnished  Area  \
# 826   Mangga Dua  Jakarta Pusat  106.827261  6.139958          1  33.0
# 951     BSD City      Tangerang  106.638100  6.304300          1  26.0
# 1140    BSD City      Tangerang  106.638100  6.304300          0  20.0
# 2344    BSD City      Tangerang  106.638100  6.304300          1  25.0
# 3143    BSD City      Tangerang  106.638100  6.304300          1  25.0
# 3175    BSD City      Tangerang  106.638100  6.304300          1  22.0
# 4469    BSD City      Tangerang  106.638100  6.304300          1  26.0
#
#             Tower  Total_Facilities Currency  Annual_Price
# 826       Tower 1                18      IDR      48000000
# 951   Tower lotus                20      IDR      40000000
# 1140   Tower Rose                17      IDR      40000000
# 2344  Tower Tulip                20      IDR      55000000
# 3143  Tower Tulip                18      IDR      55000000
# 3175  Tower Tulip                18      IDR      45000000
# 4469  Tower Tulip                19      IDR      60000000

# %% [markdown]
# There are mistaken in those values. Tangerang and Jakarta Pusat should be having negative values Latitude based upon https://www.latlong.net/place.html

# %% [markdown]
# Thus, we're gonna reverse them into negative

# %%
df_new1.loc[df_new1[df_new1.Latitude > 6].index, 'Latitude'] = -df_new1.loc[df_new1[df_new1.Latitude > 6].index, 'Latitude']


fig, ax = plt.subplots(1,2, figsize= (15,9), sharey=True)

sns.scatterplot(x='Longitude',y='Annual_Price',data=df_new1,ax=ax[0])
sns.scatterplot(x='Latitude',y='Annual_Price',data=df_new1,ax=ax[1],color='tab:orange')
plt.show()

# %% [markdown]
# The values, as shown from the graphs above, seem already reasonable and there is no extreme outliers

# %% [markdown]
# ## 2.4.4 Area and Total Facilities

# %%
fig, ax = plt.subplots(1,2, figsize= (15,9), sharey=True)

sns.scatterplot(x='Area',y='Annual_Price',data=df_new1,ax=ax[0])
sns.boxplot(x='Total_Facilities',y='Annual_Price',data=df_new1,ax=ax[1],color='tab:orange', linewidth=1.3, fliersize=4)
plt.show()

# %% [markdown]
# There are some extreme outliers in area column. They have more than 7000m2, but considered cheaper than others. Thus, we're gonna remove them.

# %% [markdown]
# On the other hand, the total facilities have some unusual values. For example like in six total facilities, there is an apartment having high price relative to its peers

# %%
df_new1 = df_new1[df_new.Area<7000]
df_new1 = df_new1[~((df_new1.Total_Facilities==6)&(df_new1.Annual_Price>0.4e9))]

fig, ax = plt.subplots(1,2, figsize= (15,9), sharey=True)

sns.scatterplot(x='Area',y='Annual_Price',data=df_new1,ax=ax[0])
sns.boxplot(x='Total_Facilities',y='Annual_Price',data=df_new1,ax=ax[1],color='tab:orange', linewidth=1.3, fliersize=4)
plt.show()

# %% [markdown]
# There are still some outliers in Area column. Let's take a look at first before we handle them for those who having more han 500m2.

# %% [markdown]
# And for the total facilities, we're also gonna check the value that has 10 total facilities with price more than Rp400,000,000

# %%
outliers1 = pd.concat([df_new1[df_new1.Area>500],df_new1[(df_new1.Total_Facilities==10)&(df_new1.Annual_Price>0.4e9)]])

# %% [markdown]
# Actually, the values above still reasonable except for "Maqna Residence 3+1BR Tower 1" in index 5019. However, again, for the robust result sake since we're gonna use PCA and Multiple Linear Regression which are sensitive to the outliers, we will take down all of the values above except for index 3611

# %%
df_new1 = df_new1.drop(index=[743,4802,5019,4812])

fig, ax = plt.subplots(1,2, figsize= (15,9), sharey=True)

sns.scatterplot(x='Area',y='Annual_Price',data=df_new1,ax=ax[0])
sns.boxplot(x='Total_Facilities',y='Annual_Price',data=df_new1,ax=ax[1],color='tab:orange', linewidth=1.3, fliersize=4)
plt.show()

# %% [markdown]
# From the left graph above, seems there are apartments that have zero area which means doesn't make any sense

# %%
df_new1[df_new1.Area==0]
# Out:
#                                               Unit_Name  No_Rooms  Bathroom  \
# 244         Menteng Square Apartment 1BR Semi Furnished         1         1
# 270                Puri Orchard Apartment 2BR View City         2         1
# 528                   Madison Park Studio Non Furnished         0         1
# 536    Green Lake Sunter Apartment 1 BR Fully Furnished         1         1
# 550   Mediterania Garden Residence 2 2BR Fully Furni...         2         1
# 558             Green Bay Pluit Apartment 3BR View city         3         2
# 797            Green Palm Residence 2BR Fully Furnished         2         1
# 810                Puri Orchard Apartment 2BR View City         2         1
# 933                       Bintaro Park View 2BR Tower B         2         1
# 1171        Sudirman Park Apartment 2BR Fully Furnished         2         1
# 1393         Green Pramuka City Apartment 2BR View City         2         2
# 1420         Poins Square Apartment 2BR Fully Furnished         2         2
# 1464                             Taman Rasuna Apartment         3         2
# 1694             Elpis Residences Apartment 2BR Tower C         2         1
# 1718                Puri Orchard Apartment 2BR Tower CH         2         1
# 1793        Bintaro Plaza Residence 2BR Fully Furnished         2         1
# 2026         Bassura City Apartment 2BR Tower Flamboyan         2         1
# 2067           Sentra Timur Residence 2BR Non Furnished         2         1
# 2724  Marbella Kemang Residence Apartment 1BR Fully ...         1         1
# 3318             Pakubuwono Terrace 2BR Fully Furnished         2         1
# 3643         Mediterania Garden Residence 2 2BR Tower H         2         1
# 4315                     Pakubuwono Terrace 2BR Tower S         2         1
# 4352      Green Park View Apartment 2BR Fully Furnished         2         1
# 861                   Tree Park BSD 1BR Fully Furnished         1         1
# 977                 The Nest Apartment Studio View City         0         1
# 1044         Serpong Green View Apartment 2BR View city         2         1
# 1243              Saveria Apartment 2BR Fully Furnished         2         1
# 1402           U Residence Karawaci 2BR Fully Furnished         2         2
# 2810  Serpong Green View Apartment Studio Semi Furni...         0         1
# 4425       M-Town Residence Serpong 2BR Fully Furnished         2         1
# 4433                U Residence Karawaci Studio Tower 1         0         1
#
#             Locality           Region   Longitude  Latitude  Furnished  Area  \
# 244          Menteng    Jakarta Pusat  106.851858 -6.200232          1   0.0
# 270       Cengkareng    Jakarta Barat  106.729326 -6.166036          1   0.0
# 528    Tanjung Duren    Jakarta Barat  106.788741 -6.178919          0   0.0
# 536           Sunter    Jakarta Utara  106.875949 -6.144770          1   0.0
# 550    Tanjung Duren    Jakarta Barat  106.788166 -6.175894          1   0.0
# 558            Pluit    Jakarta Utara  106.779326 -6.107877          1   0.0
# 797     Duri Kosambi    Jakarta Barat  106.715409 -6.174903          1   0.0
# 810       Cengkareng    Jakarta Barat  106.729326 -6.166036          1   0.0
# 933          Bintaro  Jakarta Selatan  106.759213 -6.258118          1   0.0
# 1171        Sudirman    Jakarta Pusat  106.818029 -6.205971          1   0.0
# 1393   Cempaka Putih    Jakarta Pusat  106.873191 -6.187929          0   0.0
# 1420     Lebak Bulus  Jakarta Selatan  106.778160 -6.289954          1   0.0
# 1464        Kuningan  Jakarta Selatan  106.836760 -6.218768          1   0.0
# 1694   Gunung Sahari    Jakarta Pusat  106.836638 -6.148474          1   0.0
# 1718      Cengkareng    Jakarta Barat  106.729326 -6.166036          0   0.0
# 1793         Bintaro  Jakarta Selatan  106.742800 -6.273500          1   0.0
# 2026        Cipinang    Jakarta Timur  106.879075 -6.225031          0   0.0
# 2067          Cakung    Jakarta Timur  106.948933 -6.203631          0   0.0
# 2724          Kemang  Jakarta Selatan  106.814385 -6.247255          1   0.0
# 3318  Kebayoran Lama  Jakarta Selatan  106.769194 -6.237472          1   0.0
# 3643   Tanjung Duren    Jakarta Barat  106.788166 -6.175894          1   0.0
# 4315  Kebayoran Lama  Jakarta Selatan  106.769194 -6.237472          1   0.0
# 4352      Cengkareng    Jakarta Barat  106.719271 -6.155485          1   0.0
# 861          Serpong        Tangerang  106.664798 -6.298449          1   0.0
# 977    Karang Tengah        Tangerang  106.723973 -6.195343          0   0.0
# 1044         Serpong        Tangerang  106.686600 -6.294000          1   0.0
# 1243        BSD City        Tangerang  106.652200 -6.307000          1   0.0
# 1402        Karawaci        Tangerang  106.607673 -6.228493          1   0.0
# 2810         Serpong        Tangerang  106.686600 -6.294000          0   0.0
# 4425         Serpong        Tangerang  106.632866 -6.242534          1   0.0
# 4433        Karawaci        Tangerang  106.607673 -6.228493          1   0.0
#
#                 Tower  Total_Facilities Currency  Annual_Price
# 244           Tower C                14      IDR      43300000
# 270        Tower OG B                19      IDR      60000000
# 528    Tower Magnolia                16      IDR      27000000
# 536      Tower slatan                20      IDR      55000000
# 550           Tower K                23      IDR      60000000
# 558           Tower K                21      IDR     175000000
# 797           Tower B                19      IDR      30000000
# 810          Tower OG                20      IDR      55000000
# 933           Tower B                20      IDR      55000000
# 1171          Tower B                24      IDR      84000000
# 1393       Tower Pino                20      IDR      48000000
# 1420          Tower A                23      IDR     108000000
# 1464         Tower 17                24      IDR     133000000
# 1694          Tower C                21      IDR      75000000
# 1718         Tower CH                16      IDR      42000000
# 1793      Tower Altiz                16      IDR      81600000
# 2026  Tower Flamboyan                19      IDR      48000000
# 2067      Tower Tosca                14      IDR      19000000
# 2724          Tower B                24      IDR      72000000
# 3318    Tower Selatan                19      IDR      80000000
# 3643          Tower H                24      IDR      60000000
# 4315          Tower S                20      IDR      64800000
# 4352          Tower F                20      IDR      32000000
# 861           Tower -                 8      IDR      65000000
# 977           Tower B                14      IDR      32400000
# 1044          Tower b                16      IDR      55000000
# 1243      Tower South                16      IDR      60000000
# 1402          Tower 1                20      IDR     110000000
# 2810  Tower Beachwood                15      IDR      27600000
# 4425   Tower Franklin                17      IDR      64000000
# 4433          Tower 1                19      IDR      45000000

# %% [markdown]
# In this issue, I hypothesize that an error occurred while entering the data.

# %%
df_new1[df_new1.Area==0].shape
# Out:
# (31, 13)

# %% [markdown]
# In addition, since the total number of zero area apartments is only 31, we can fill in manually to get the most accurate possible value by checking through the internet.

# %% [markdown]
# *Otherwise, if the number is big enough that would be taking a lot of time, we may use statistical methods instead*

# %%
df_new1.loc[244, 'Area'] = 27
df_new1.loc[270, 'Area'] = 21
df_new1.loc[528, 'Area'] = 18.16
df_new1.loc[536, 'Area'] = 42
df_new1.loc[550, 'Area'] = 44
df_new1.loc[558, 'Area'] = 60
df_new1.loc[797, 'Area'] = 36
df_new1.loc[810, 'Area'] = 21
df_new1.loc[933, 'Area'] = (38+22)/2
df_new1.loc[1171, 'Area'] = 48
df_new1.loc[1393, 'Area'] = 33
df_new1.loc[1420, 'Area'] = 82
df_new1.loc[1464, 'Area'] = 70
df_new1.loc[1694, 'Area'] = 42
df_new1.loc[1718, 'Area'] = 50
df_new1.loc[1793, 'Area'] = 40
df_new1.loc[2026, 'Area'] = 38
df_new1.loc[2067, 'Area'] = 36
df_new1.loc[2724, 'Area'] = 92
df_new1.loc[3318, 'Area'] = 38
df_new1.loc[3643, 'Area'] = 44
df_new1.loc[4315, 'Area'] = 49
df_new1.loc[4352, 'Area'] = 42
df_new1.loc[861, 'Area'] = 40
df_new1.loc[1044, 'Area'] = 39
df_new1.loc[1402, 'Area'] = 66
df_new1.loc[2810, 'Area'] = 22
df_new1.loc[4425, 'Area'] = 30
df_new1.loc[4433, 'Area'] = 35

df_new1.drop(index=[977,1243],inplace=True) #Both of these apartments are nowhere to be found on the internet

# %%
fig, ax = plt.subplots(1,2, figsize= (15,9), sharey=True)

sns.scatterplot(x='Area',y='Annual_Price',data=df_new1,ax=ax[0])
sns.boxplot(x='Total_Facilities',y='Annual_Price',data=df_new1,ax=ax[1],color='tab:orange', linewidth=1.3, fliersize=4)
plt.show()

# %%
df_new1[df_new1.Area<=10]
# Out:
#                                               Unit_Name  No_Rooms  Bathroom  \
# 2482              Lavenue Apartment 2BR Fully Furnished         2         2
# 3632  Kalibata City Green Palace Studio Tower Nusa I...         0         1
# 898                 Aeropolis 2 Apartment 1BR View city         1         1
# 2137            Aeropolis 2 Apartment 1BR Non Furnished         1         1
# 4576        Aeropolis 2 Apartment 1BR Tower Residence 3         1         1
#
#         Locality           Region   Longitude  Latitude  Furnished  Area  \
# 2482    Pancoran  Jakarta Selatan  106.842971 -6.248050          1   6.0
# 3632    Kalibata  Jakarta Selatan  106.849866 -6.257697          1   3.0
# 898   Cengkareng        Tangerang  106.632900 -6.128300          0  10.0
# 2137  Cengkareng        Tangerang  106.632900 -6.128300          0  10.0
# 4576  Cengkareng        Tangerang  106.632900 -6.128300          0  10.0
#
#                   Tower  Total_Facilities Currency  Annual_Price
# 2482        Tower North                22      IDR     186000000
# 3632   Tower Nusa Indah                24      IDR      43200000
# 898   Tower Residence 3                 3      IDR      19600000
# 2137  Tower Residence 3                 3      IDR      19600000
# 4576  Tower Residence 3                 3      IDR      19600000

# %%
df_new1.loc[2482, 'Area'] = 106
df_new1.loc[3632, 'Area'] = 21

# %%
fig, ax = plt.subplots(1,2, figsize= (15,9), sharey=True)

sns.scatterplot(x='Area',y='Annual_Price',data=df_new1,ax=ax[0])
sns.boxplot(x='Total_Facilities',y='Annual_Price',data=df_new1,ax=ax[1],color='tab:orange', linewidth=1.3, fliersize=4)
plt.show()

# %% [markdown]
# ## 2.4.5 Furnished

# %%
sns.boxplot(x='Furnished',y='Annual_Price',data=df_new1, linewidth=1.3, fliersize=4)
plt.show()

# %% [markdown]
# # 3. Feature Engineering

# %% [markdown]
# ## 3.1 Create New feature for representing Latitude and Longitude by using Clustering method

# %%
df_cluster = df_new1[['Longitude','Latitude','Annual_Price']]
df_cluster.sample(6)
# Out:
#        Longitude  Latitude  Annual_Price
# 4342  106.756061 -6.192081      36000000
# 4122  106.729326 -6.166036      50050000
# 1891  106.990600 -6.251900      36000000
# 3973  106.835616 -6.188741     198000000
# 923   106.791700 -6.179200      53000000
# 4282  106.765123 -6.216423      37500000

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
scaler = StandardScaler()
df_cluster_new = scaler.fit_transform(df_cluster)
df_cluster_new = pd.DataFrame(df_cluster_new,columns=df_cluster.columns,index=df_cluster.index)

# %%
inertia = []

for k in range(2, 15):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(df_cluster_new)
    inertia.append(kmeans.inertia_)

# %%
plt.plot(inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum of squared distance')
plt.title('Elbow Method for finding optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(df_cluster_new)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
df_cluster_new['cluster'] = kmeans.labels_
df_cluster_new.head(20)
# Out:
#     Longitude  Latitude  Annual_Price  cluster
# 0    0.115506 -0.425952     -0.078576        1
# 1   -0.828816  0.302039     -0.742179        0
# 2   -0.805021  0.421539     -0.339995        0
# 3   -0.401703 -1.396951      4.747631        2
# 4   -0.230253  1.112537     -0.722070        0
# 5    0.924147  0.389608     -0.440541        0
# 6    0.578673  1.209175     -0.239449        0
# 7    0.000178 -1.117224      1.369286        2
# 8    0.604549 -1.070592     -0.587338        1
# 9    0.924147  0.389608     -0.712015        0
# 10   1.339647  0.799739     -0.701961        0
# 11   1.081874  1.030810     -0.802507        0
# 12   1.315343 -0.372824     -0.691906        1
# 13   0.378922 -0.260811     -0.187165        1
# 14  -1.138028  1.069343     -0.691906        0
# 15   0.471876 -0.878392      0.162735        1
# 16  -0.828816  0.302039     -0.561196        0
# 17  -0.632268 -0.655293     -0.606442        1
# 18  -0.734007  0.132785     -0.661742        0
# 19  -0.299799 -1.614777      0.464373        1

# %%
fig, ax = plt.subplots(1,2, figsize= (15,5), sharey=True)

sns.scatterplot(x=df_new1['Longitude'], y=df_new1['Annual_Price'],ax=ax[0], hue=df_cluster_new['cluster'], palette='rainbow')
sns.scatterplot(x=df_new1['Latitude'], y=df_new1['Annual_Price'],hue=df_cluster_new['cluster'], palette='rainbow')
plt.show()

# %%
sns.scatterplot(x=df_new1['Latitude'], y=df_new1['Longitude'], hue=df_cluster_new['cluster'], palette='rainbow')
plt.show()

# %% [markdown]
# - Cluster 0 = North area and slight west apartments that have quite affordable prices relative to others ( Sunter, Daan Mogot, Kebon Jeruk, Tanah Abang, Senen, etc )
# - Cluster 1 = South area and slight east apartments that have quite affordable prices relative to others ( Cikarang, Bekasi, Margonda, Kebagusan, Cawang, Ciputat )
# - Cluster 2 = Pricy apartments and most of them located in the middle of distribution longitude and latitude ( Kemang, Pondok Indah, SCBD, Cilandak, BSD City, etc )

# %%
df_new1['cluster'] = df_cluster_new['cluster']
df_new1.sample(6)
# Out:
#                                             Unit_Name  No_Rooms  Bathroom  \
# 409          The Mansion Kemang 1BR Tower south tower         1         1
# 4817       SkyLounge Apartment Studio Fully Furnished         0         1
# 1970                            Kemang Village Studio         0         1
# 5006   Kalibata City Green Palace 2BR Fully Furnished         2         1
# 1751      Ancol Mansion Apartment 1BR Fully Furnished         1         1
# 32    The Mansion Kemayoran Jasmine 2BR Non Furnished         2         1
#
#            Locality           Region   Longitude  Latitude  Furnished  Area  \
# 409          Kemang  Jakarta Selatan  106.810318 -6.255134          1  64.0
# 4817  Karang Tengah        Tangerang  106.636633 -6.154271          1  21.0
# 1970         Kemang  Jakarta Selatan  106.811453 -6.259374          1  43.0
# 5006       Kalibata  Jakarta Selatan  106.849866 -6.257697          1  42.0
# 1751          Ancol    Jakarta Utara  106.845853 -6.122102          1  65.0
# 32        Kemayoran    Jakarta Pusat  106.854936 -6.147823          0  49.0
#
#                   Tower  Total_Facilities Currency  Annual_Price  cluster
# 409   Tower south tower                22      IDR     132000000        1
# 4817            Tower 1                18      IDR      32000000        0
# 1970     Tower Intercon                13      IDR     132000000        1
# 5006        Tower Mawar                21      IDR      72000000        1
# 1751           Tower AO                24      IDR      76700000        0
# 32     Tower Bellavista                17      IDR      60000000        0

# %% [markdown]
# # 4. Perform Factor Analysis

# %% [markdown]
# Factor Analysis is a method for grouping various independent variables if we assume that there is a relationship between these independent variables

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity,calculate_kmo, FactorAnalyzer
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Uji Hipotesis Bartlett Sphericity**

# %%
df_num1 = df_new1[df_new1['Currency']=='IDR'].select_dtypes(exclude='object').drop(['Longitude','Latitude'],axis=1)
scaler = StandardScaler()
df_num = scaler.fit_transform(df_num1.drop('Annual_Price',axis=1))
df_num = pd.DataFrame(df_num,columns=df_num1.drop('Annual_Price',axis=1).columns)

# %% [markdown]
# - Hypothesis 0: No 'factor' can be formed from the independent variables in our data
# - Hypothesis alternative: There is 'factor' that can be formed from the independent variables of our data
# - p-value = 0, meaning we can reject the 0 hypothesis. This means that there is 'factor' that can be formed from the independent variables in our data.

# %%
chi2,p = calculate_bartlett_sphericity(df_num)
print("Bartlett Sphericity Test")
print("Chi squared value : ",chi2)
print("p value : ",p)
# Out:
# Bartlett Sphericity Test
# Chi squared value :  9901.549682134751
# p value :  0.0

# %% [markdown]
# **Uji KMO (KAISER-MEYER-OLKIN)**

# %% [markdown]
# KMO is a test conducted to determine the appropriateness of a factor analysis to be carried out. The KMO test scale ranges from 0 to 1. If the calculated KMO value is lower than 0.5, then factor analysis is not feasible. Meanwhile, if the calculated KMO value is greater than 0.5, then factor analysis is feasible

# %%
kmo_all,kmo_model = calculate_kmo(df_num)
print("KMO Test Statisitc",kmo_model)
# Out:
# KMO Test Statisitc 0.6969293066746926

# %%
fa = FactorAnalyzer(rotation=None,n_factors=3)
fa.fit(df_num)
# Out:
# FactorAnalyzer(rotation=None, rotation_kwargs={})

# %%
ev,_ = fa.get_eigenvalues()

# %%
plt.scatter(range(1,df_num.shape[1]+1),ev)
plt.plot(range(1,df_num.shape[1]+1),ev)
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigen Value')
plt.grid(True)

# %%
fa = FactorAnalyzer(n_factors=3)
fa.fit(df_num)
pd.DataFrame(fa.loadings_,index=df_num.columns)
# Out:
#                          0         1         2
# No_Rooms          0.695642  0.063510 -0.093360
# Bathroom          0.762370 -0.064927  0.112204
# Furnished        -0.082611  0.450199  0.121052
# Area              0.903397 -0.012850  0.108367
# Total_Facilities  0.158442  1.009178 -0.187353
# cluster           0.072795  0.014153  0.830648

# %%
plt.subplots(figsize=(10,15))
sns.heatmap(pd.DataFrame(fa.loadings_,index=df_num.columns),cmap='Blues',annot=True)
plt.show()

# %%
pd.DataFrame(fa.get_factor_variance(),index=['Variance','Proportional Var','Cumulative Var'])
# Out:
#                          0         1         2
# Variance          1.918481  1.229733  0.772781
# Proportional Var  0.319747  0.204956  0.128797
# Cumulative Var    0.319747  0.524702  0.653499

# %%
sns.heatmap(pd.DataFrame(df_num.drop('Furnished',axis=1).corr(),index=df_num.drop('Furnished',axis=1).columns),cmap='Blues',annot=True)
plt.show()

# %%
X = pd.DataFrame(fa.transform(df_num),columns=['Main_Features','Amenities','Location'],index=df_num.index)
df_cleaned = pd.concat([X,df_num1.Annual_Price.reset_index(drop=True)],axis=1)
df_cleaned.drop(index=[3120,3263],inplace=True)

# %%
fig, ax = plt.subplots(1,3, figsize= (15,9), sharey=True)

sns.scatterplot(x='Main_Features',y='Annual_Price',data=df_cleaned,ax=ax[0])
sns.scatterplot(x='Amenities',y='Annual_Price',data=df_cleaned,ax=ax[1],color='tab:orange')
sns.scatterplot(x='Location',y='Annual_Price',data=df_cleaned,ax=ax[2],color='tab:green')
plt.show()

# %%
sns.heatmap(df_cleaned.corr(),cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# # 5. Perform Linear Regression

# %% [markdown]
# ## 5.1 Model Diagnostic and Checking Assumptions

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df_cleaned, df_test = train_test_split(df_cleaned, test_size = 0.2, random_state=0)

lr = LinearRegression()
lr.fit(df_cleaned.drop(['Annual_Price'],axis=1),np.log(df_cleaned.Annual_Price))
# 
# calculate residuals
predicted_values = lr.predict(df_cleaned.drop(['Annual_Price'],axis=1))
residual = np.log(df_cleaned.Annual_Price) - predicted_values

#preprocess shape

# prepare dataframe
# >1 predictor --> predicted value VS residual
df_resid = pd.DataFrame({
    'x_axis': predicted_values,
    'residual': residual
})

# residual plot
sns.scatterplot(data=df_resid, x="x_axis", y="residual",color='#29ba74ff')
plt.axhline(0,color='tab:blue')
plt.show()

# %% [markdown]
# ### 5.1.1 Linearity

# %% [markdown]
# From the residual plot above, there is no non-linear pattern exists. Thus, linearity assumption is met

# %% [markdown]
# ### 5.1.2 Normality

# %%
# QQplot
from sklearn.preprocessing import StandardScaler



std_resid = StandardScaler().fit_transform(residual[(residual>-0.7e8)&(residual<0.7e8)].values.reshape(-1,1))
std_resid = np.array([value for nested_array in std_resid for value in nested_array])

import statsmodels.api as sm
sm.qqplot(std_resid, line='45')
plt.show()

# %%
from scipy.stats import jarque_bera, bartlett


jarque_bera(std_resid)
# Out:
# Jarque_beraResult(statistic=0.7299673090336198, pvalue=0.6942079979504029)

# %% [markdown]
# Since the p-value is more than 0.05, then it can be concluded that normality assumption is met

# %% [markdown]
# ### 5.1.3 Heteroscedasticity

# %%
import statsmodels.stats.api as sms
from statsmodels.compat import lzip

X = df_cleaned.drop('Annual_Price',axis=1)

name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(residual, X)
lzip(name, test)
# Out:
# [('F statistic', 0.9792823928069616), ('p-value', 0.6627101711361199)]

# %% [markdown]
# Since the p-value is more than 0.05, then it can be concluded that heteroscedasticity assumption is met

# %%
import statsmodels.api as sm

X = sm.add_constant(df_cleaned.drop(['Annual_Price'],axis=1))
model = sm.OLS(np.log(df_cleaned.Annual_Price), X)
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Annual_Price   R-squared:                       0.726
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     2841.
# Date:                Sun, 11 Dec 2022   Prob (F-statistic):               0.00
# Time:                        01:38:11   Log-Likelihood:                -1481.4
# No. Observations:                3225   AIC:                             2971.
# Df Residuals:                    3221   BIC:                             2995.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            18.1364      0.007   2686.905      0.000      18.123      18.150
# Main_Features     0.4676      0.008     55.930      0.000       0.451       0.484
# Amenities         0.1070      0.007     14.962      0.000       0.093       0.121
# Location          0.2581      0.009     27.882      0.000       0.240       0.276
# ==============================================================================
# Omnibus:                        0.709   Durbin-Watson:                   2.071
# Prob(Omnibus):                  0.701   Jarque-Bera (JB):                0.730
# Skew:                           0.036   Prob(JB):                        0.694
# Kurtosis:                       2.981   Cond. No.                         1.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 5.1.4 Independence

# %% [markdown]
# From the summary result above, the value of Durbin-Watson closes to 2. Therefore, it implies that Independence assumption is met

# %% [markdown]
# ## 5.2 Cross Validation

# %%
from sklearn.model_selection import cross_val_score

linreg = LinearRegression()
X = df_cleaned.drop('Annual_Price',axis=1)
y = np.log(df_cleaned.Annual_Price)

cv_results = (-cross_val_score(linreg, X,y, cv=5,scoring='neg_mean_squared_error',n_jobs=-1))
cv_results1 = (cross_val_score(linreg, X,y, cv=5,scoring='r2',n_jobs=-1))

# %%
pd.DataFrame(np.sqrt(cv_results),columns=['Root Mean Squared Error'])
# Out:
#    Root Mean Squared Error
# 0                 0.384589
# 1                 0.386515
# 2                 0.386428
# 3                 0.371876
# 4                 0.387875

# %%
print('The average of RMSE from 5 cross validation',np.sqrt(cv_results).mean())
print('The standard deviation of RMSE from 5 cross validation',np.sqrt(cv_results).std())
# Out:
# The average of RMSE from 5 cross validation 0.3834565051622848
# The standard deviation of RMSE from 5 cross validation 0.005883774501142338

# %%
pd.DataFrame(cv_results1,columns=['R-Squared'])
# Out:
#    R-Squared
# 0   0.731285
# 1   0.699931
# 2   0.727433
# 3   0.735627
# 4   0.728173

# %%
print('The average of R-Squared from 5 cross validation',cv_results1.mean())
print('The standard deviation of R-Squared from 5 cross validation',cv_results1.std())
# Out:
# The average of R-Squared from 5 cross validation 0.724489870555552
# The standard deviation of R-Squared from 5 cross validation 0.012614083120011837

# %% [markdown]
# ## 5.3 Testing the model

# %%
X_train = df_cleaned.drop('Annual_Price',axis=1)
y_train = np.log(df_cleaned.Annual_Price)
X_test = df_test.drop('Annual_Price',axis=1)
y_test = np.log(df_test.Annual_Price)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

def scores(model, name):
    test_val = y_test.values.tolist()
    prediction = model.predict(X_test)    
        
    sns.scatterplot(x=test_val, y=prediction)
    plt.xlabel('Actual Price')
    plt.ylabel('Predicted Price')
    score = pd.Series({'Model':name,
              'RMSE_train': mean_squared_error(y_train, model.predict(X_train)),
              'RMSE_test': mean_squared_error(y_test, model.predict(X_test)),
              'R2_train': r2_score(y_train, model.predict(X_train)),
              'R2_test': r2_score(y_test, model.predict(X_test))
             })
    return score

# %%
scores(lr, 'Linear Regression')
# Out:
# Model         Linear Regression
# RMSE_train             0.146726
# RMSE_test              0.153216
# R2_train               0.725717
# R2_test                0.699468
# dtype: object
